# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ASUS\Documents\-em-bond-macro-analysis\data\Cleaned\panel_monthly_2010_2024_copy.csv")
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(['country','date'])
numeric_cols = ['yield_10y','CPI_annual_pct','GDP_growth_annual_pct','External_debt_usd','usd_index','brent']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric)

# %%
df
# Out:
#           date country  yield_10y  CPI_annual_pct  GDP_growth_annual_pct  \
# 0   2010-06-30  Brazil     12.788        5.038727               7.528226
# 1   2010-07-31  Brazil     12.010        5.038727               7.528226
# 2   2010-08-31  Brazil     11.510        5.038727               7.528226
# 3   2010-09-30  Brazil     12.020        5.038727               7.528226
# 4   2010-10-31  Brazil     11.920        5.038727               7.528226
# ..         ...     ...        ...             ...                    ...
# 978 2024-08-31  Turkey     26.730       58.506451               3.184024
# 979 2024-09-30  Turkey     26.620       58.506451               3.184024
# 980 2024-10-31  Turkey     28.460       58.506451               3.184024
# 981 2024-11-30  Turkey     27.350       58.506451               3.184024
# 982 2024-12-31  Turkey     27.150       58.506451               3.184024
#
#      External_debt_usd   usd_index      brent
# ...

# %%
# To see how various variables move with time. Are there any trends, spikes or seasonality? Check for distributions and outliers.

# %%
# Date vs Yield

import matplotlib.pyplot as plt
import seaborn as sns

countries = df['country'].unique()

for c in countries:
    temp = df[df['country']==c]
    plt.figure(figsize=(12,6))
    plt.plot(temp['date'], temp['yield_10y'], marker='o')
    plt.title(f'10-Year Yield Over Time - {c}')
    plt.xlabel('Date')
    plt.ylabel('10-Year Yield (%)')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# %%
# Date vs CPI

countries = df['country'].unique()

for c in countries:
    temp = df[df['country']==c]
    plt.figure(figsize=(12,6))
    plt.plot(temp['date'], temp['CPI_annual_pct'], marker='o')
    plt.title(f'CPI Over Time - {c}')
    plt.xlabel('Date')
    plt.ylabel('CPI Annual (%)')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# %%
# CPI, External Debt and GDP Growth have been forward filled for all the months of the year because of the annual nature of their values

# %%
# Date vs GDP Growth

countries = df['country'].unique()

for c in countries:
    temp = df[df['country']==c]
    plt.figure(figsize=(12,6))
    plt.plot(temp['date'], temp['GDP_growth_annual_pct'], marker='o')
    plt.title(f'GDP Growth Over Time - {c}')
    plt.xlabel('Date')
    plt.ylabel('GDP Growth Annual (%)')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# %%
# Date vs External Debt

countries = df['country'].unique()

for c in countries:
    temp = df[df['country']==c]
    plt.figure(figsize=(12,6))
    plt.plot(temp['date'], temp['External_debt_usd'], marker='o')
    plt.title(f'External Debt Over Time - {c}')
    plt.xlabel('Date')
    plt.ylabel('External Debt USD')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# %%
# Debt/GDP ratio gives a better picture of whether a country will be able to pay for the bonds issued. But unavailability of nominal GDP values led to individual understanding of GDP Growth and External Debt.

# %%
# Date vs USD Index

countries = df['country'].unique()

for c in countries:
    temp = df[df['country']==c]
    plt.figure(figsize=(12,6))
    plt.plot(temp['date'], temp['usd_index'], marker='o')
    plt.title(f'USD Index Over Time - {c}')
    plt.xlabel('Date')
    plt.ylabel('USD Index')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# %%
# Date vs Brent Crude Oil Prices

countries = df['country'].unique()

for c in countries:
    temp = df[df['country']==c]
    plt.figure(figsize=(12,6))
    plt.plot(temp['date'], temp['brent'], marker='o')
    plt.title(f'Brent Crude Oil Prices Over Time - {c}')
    plt.xlabel('Date')
    plt.ylabel('Brent Crude Oil Prices')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# %%
# Scatter Plots to check relationship

# %%
for c in countries:
    temp = df[df['country']==c]
    plt.figure(figsize=(12,6))
    sns.scatterplot(x='CPI_annual_pct', y='yield_10y', data=temp)
    plt.title(f'Yield vs CPI - {c}')
    plt.xlabel('CPI (%)')
    plt.ylabel('10-Year Yield (%)')
    plt.grid(True)
    plt.show()

# %%
for c in countries:
    temp = df[df['country']==c]
    plt.figure(figsize=(12,6))
    sns.scatterplot(x='GDP_growth_annual_pct', y='yield_10y', data=temp)
    plt.title(f'Yield vs GDP Growth - {c}')
    plt.xlabel('GDP Growth (%)')
    plt.ylabel('10-Year Yield (%)')
    plt.grid(True)
    plt.show()

# %%
for c in countries:
    temp = df[df['country']==c]
    plt.figure(figsize=(12,6))
    sns.scatterplot(x='External_debt_usd', y='yield_10y', data=temp)
    plt.title(f'Yield vs External Debt - {c}')
    plt.xlabel('External Debt (USD)')
    plt.ylabel('10-Year Yield (%)')
    plt.grid(True)
    plt.show()

# %%
for c in countries:
    temp = df[df['country']==c]
    plt.figure(figsize=(12,6))
    sns.scatterplot(x='usd_index', y='yield_10y', data=temp)
    plt.title(f'Yield vs USD Index - {c}')
    plt.xlabel('USD Index')
    plt.ylabel('10-Year Yield (%)')
    plt.grid(True)
    plt.show()

# %%
for c in countries:
    temp = df[df['country']==c]
    plt.figure(figsize=(12,6))
    sns.scatterplot(x='brent', y='yield_10y', data=temp)
    plt.title(f'Yield vs Brent Crude Oil Prices - {c}')
    plt.xlabel('Brent Crude Oil Prices')
    plt.ylabel('10-Year Yield (%)')
    plt.grid(True)
    plt.show()

# %%
# Correlation Matrix for a quick summary of linear relationships

# %%
for c in countries:
    temp = df[df['country']==c]
    corr = temp[numeric_cols].corr()
    plt.figure(figsize=(8,6))
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title(f'Correlation Matrix - {c}')
    plt.show()
